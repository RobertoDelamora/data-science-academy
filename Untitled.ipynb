# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

figure, ax = plt.subplots(figsize=(11, 6))
plt.plot()
plt.xticks(np.arange(0, 3001, 500), fontsize=13)
plt.yticks(np.arange(0, 501, 100), fontsize=13)
plt.grid(True)
plt.title('Housing Prices - Portland, OR', fontsize=20, fontweight='bold')
plt.xlabel('Size (feet²)', fontsize=15, labelpad=10)
plt.ylabel('Price (*$1000)', fontsize=15, labelpad=10)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1, 2, 3], [1, 2, 3], 'rx', markersize=12)
plt.grid(False)
plt.xticks([0, 1, 2, 3], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlabel('x', fontsize=23)
plt.ylabel('y', fontsize=23, rotation=0, labelpad=15)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
#plt.plot([0, 1, 2, 3], [0, 1, 2, 3], color='black', label='h(x)')
plt.grid(False)
plt.xticks([0, .5, 1, 1.5, 2, 2.5], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 2.5])
plt.ylim([0, 3])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=17)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1, 2, 3], [1, 2, 3], 'rx', markersize=12)
plt.plot([0, 1, 2, 3], [0, 1, 2, 3], color='black', label='h(x)')
plt.grid(False)
plt.xticks([0, 1, 2, 3], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlabel('x', fontsize=23)
plt.ylabel('y', fontsize=23, rotation=0, labelpad=15)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1], [0], 'ro', markersize=12)
#plt.plot([0, 1, 2, 3], [0, 1, 2, 3], color='black', label='h(x)')
plt.grid(False)
plt.xticks([0, .5, 1, 1.5, 2, 2.5], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 2.5])
plt.ylim([0, 3])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=17)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1, 2, 3], [1, 2, 3], 'rx', markersize=12)
plt.plot([0, 1, 2, 3], [0, .5, 1, 1.5], color='black', label='h(x)')
plt.plot([1, 1], [1, .5], '--', color='b')
plt.plot([2, 2], [2, 1], '--', color='b')
plt.plot([3, 3], [3, 1.5], '--', color='b')
plt.plot([1, 2, 3], [.5, 1, 1.5], 'ro', color='r', markersize=5)
plt.grid(False)
plt.xticks([0, 1, 2, 3], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlabel('x', fontsize=23)
plt.ylabel('y', fontsize=23, rotation=0, labelpad=15)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1], [0], 'ro', markersize=12)
plt.plot([.5], [.58], 'ro', markersize=12)
plt.grid(False)
plt.xticks([0, .5, 1, 1.5, 2, 2.5], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 2.5])
plt.ylim([0, 3])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=17)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1, 2, 3], [1, 2, 3], 'rx', markersize=12)
plt.plot([0, 1, 2, 3], [0, 0, 0, 0], color='black', label='h(x)')
plt.plot([1, 1], [1, 0], '--', color='b')
plt.plot([2, 2], [2, 0], '--', color='b')
plt.plot([3, 3], [3, 0], '--', color='b')
plt.plot([1, 2, 3], [0, 0, 0], 'ro', color='r', markersize=5)
plt.grid(False)
plt.xticks([0, 1, 2, 3], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 3.2])
plt.ylim([0, 3.2])
plt.xlabel('x', fontsize=23)
plt.ylabel('y', fontsize=23, rotation=0, labelpad=15)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1], [0], 'ro', markersize=12)
plt.plot([.5], [.58], 'ro', markersize=12)
plt.plot([0], [2.33], 'ro', markersize=12)
plt.grid(False)
plt.xticks([0, .5, 1, 1.5, 2, 2.5], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 2.5])
plt.ylim([0, 3])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=17)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
sns.despine()
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1, 2, 3], [1, 2, 3], 'rx', markersize=12)
plt.plot([0, 1, 2, 3], [0, 1.2, 2.4, 3.6], '--', color='black')
plt.plot([0, 1, 2, 3], [0, 1, 2, 3], '--', color='black')
plt.plot([0, 1, 2, 3], [0, .75, 1.5, 2.25], '--', color='black')
plt.plot([0, 1, 2, 3], [0, .5, 1, 1.5], '--', color='black')
plt.plot([0, 1, 2, 3], [0, .2, .4, .6], '--', color='black')
plt.plot([0, 1, 2, 3], [0, 0, 0, 0], color='black')
plt.plot([1, 2, 3], [0, 0, 0], 'ro', color='r', markersize=5)
plt.grid(False)
plt.xticks([0, 1, 2, 3], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 3.2])
plt.ylim([0, 3.2])
plt.xlabel('x', fontsize=23)
plt.ylabel('y', fontsize=23, rotation=0, labelpad=15)
sns.despine()
#plt.legend(loc='center right', fontsize=15)
plt.show()

# %%
fig = plt.Figure()
plt.figure(figsize=(7, 5))
lines = ax.plot
plt.plot([1], [0], 'ro', markersize=12)
plt.plot([.5], [.58], 'ro', markersize=12)
plt.plot([0], [2.33], 'ro', markersize=12)
plt.plot([1.5], [.58], 'ro', markersize=12)
plt.plot([2], [2.33], 'ro', markersize=12)
plt.grid(False)
plt.xticks([0, .5, 1, 1.5, 2, 2.5], fontsize=15)
plt.yticks([0, 1, 2, 3], fontsize=15)
plt.xlim([0, 2.5])
plt.ylim([0, 3])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=17)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
sns.despine()
plt.show()

# %%
import matplotlib.pyplot as plt

a=[]
b=[]
# y=0
# x=-50
x = -10
#for x in range(-50,50):
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure()
plt.plot(a,b)
plt.xlim([-2, 4])
plt.ylim([0, 30])
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.plot([3], [20], 'ro')
plt.plot([3, 3], [0, 20], '--', color='black')
#plt.plot([1, 1], [1, 0], '--', color='b')
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.plot([2.3], [10.5], 'ro')
plt.plot([2.3, 2.3], [0, 10.5], '--', color='black')
#plt.plot([1, 1], [1, 0], '--', color='b')
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.plot([3], [20], 'ro')
plt.plot([3, 3], [0, 20], '--', color='black')
plt.plot([2.3], [10.5], 'ro')
plt.plot([2.3, 2.3], [0, 10.5], '--', color='black')
#plt.plot([1, 1], [1, 0], '--', color='b')
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.plot([-1.2], [12.8], 'ro')
plt.plot([-1.2, -1.2], [0, 12.8], '--', color='black')
#plt.plot([1, 1], [1, 0], '--', color='b')
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()

# %%
a=[]
b=[]
x = -10
while x < 10:
    y=((177/50)*x**2)-((467/100)*x)+233/100
    a.append(x)
    b.append(y)
    x= x+.1
fig= plt.figure(figsize=(9, 6))
plt.plot(a,b)
plt.plot([-1.2], [12.8], 'ro')
#plt.plot([-1.2, -1.2], [0, 12.8], '--', color='black')
plt.plot([-0.6], [6.4], 'ro')
#plt.plot([-1.2, -1.2], [0, 12.8], '--', color='black')
plt.plot([-0.2], [3.3], 'ro')
#plt.plot([-1.2, -1.2], [0, 12.8], '--', color='black')
plt.plot([0.588], [0.8], 'ro')
#plt.plot([-1.2, -1.2], [0, 12.8], '--', color='black')
plt.xlim([-2.5, 4])
plt.ylim([0, 30])
plt.ylabel(r"$J({\Theta_1})$", fontsize=15, rotation=0, labelpad=22)
plt.xlabel(r'${\Theta_1}$', fontsize=15, labelpad=10)
plt.title('Any Cost Function', fontsize=15)
plt.show()
